# %%
import pickle
import pandas as pd
import numpy as np
import statsmodels.api as sm 
import statsmodels.formula.api as smf

# read data
with open('data_clean.dat') as f:
    data, subjects = pickle.load(f)
f.close()


# adding subject ids
for i in range(len(data)):
    #data[i]['subject'] = pd.Series(i+np.zeros(data[i].shape[0]), index=data[i].index, dtype=int)
    data[i]['subject'] = pd.Series(np.repeat(subjects[i],data[i].shape[0],axis=0), index=data[i].index, dtype=str)

del subjects

# concatenatig into a single dataframe
data_all = pd.concat(data, axis=0)
data_all = data_all.reset_index(drop=True)

# keeping only relevant variables
data_all = data_all[['subject','mood','quality','mood_prev', 'act_prev', 'stress_prev', 'energy_prev', 'daytype']]

# removing nan rows
data_all = data_all.dropna()
data_all = data_all.reset_index(drop=True)

n_boot = 10

#for i in range

md = smf.glm('mood ~ quality + act_prev + stress_prev + energy_prev + mood_prev + daytype', data_all)
mdf = md.fit()
print mdf.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   mood   No. Observations:                 5819
# Model:                            GLM   Df Residuals:                     5812
# Model Family:                Gaussian   Df Model:                            6
# Link Function:               identity   Scale:                  0.767405551281
# Method:                          IRLS   Log-Likelihood:                -7483.0
# Date:                Fri, 17 Feb 2017   Deviance:                       4460.2
# Time:                        14:18:40   Pearson chi2:                 4.46e+03
# No. Iterations:                     4
# ===============================================================================
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       0.8319      0.045     18.658      0.000         0.745     0.919
# quality         0.2242      0.008     28.930      0.000         0.209     0.239
# act_prev       -0.0001      0.000     -1.088      0.276        -0.000     0.000
# stress_prev     0.0343      0.010      3.377      0.001         0.014     0.054
# energy_prev     0.0275      0.012      2.259      0.024         0.004     0.051
# mood_prev       0.5823      0.013     43.140      0.000         0.556     0.609
# daytype         0.0061      0.012      0.504      0.614        -0.018     0.030
# ===============================================================================

# %%
data_all
# Out:
#       subject      mood  quality  mood_prev  act_prev  stress_prev  \
# 0     EW057EV  1.500000      2.0   0.666667      20.0     0.666667
# 1     EW057EV  3.000000      0.0   1.500000      35.0     1.000000
# 2     EW057EV  2.000000      1.0   3.000000      45.0     1.333333
# 3     EW057EV  4.000000      2.0   2.000000      19.0     2.000000
# 4     EW057EV  3.666667      3.0   4.000000      51.0     2.666667
# 5     EW057EV  1.666667      2.0   3.666667      32.0     3.000000
# 6     EW057EV  2.000000      1.0   1.666667      74.0     2.333333
# 7     EW057EV  1.666667      1.0   2.000000      31.0     1.333333
# 8     EW057EV  0.500000      0.0   1.666667      46.0     0.333333
# 9     EW057EV  2.000000      4.0   0.500000     141.0     0.000000
# 10    EW057EV  0.666667      1.0   2.000000      55.0     1.000000
# 11    EW057EV  1.000000      1.0   0.666667      14.0     0.333333
